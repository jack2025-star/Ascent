# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. 读取数据

# %%
# 读取身高和体重数据集，将第一列作为索引输出，预览前五行
# Out:
#        Weight(Pounds)  Height(Inches)
# Index
# 1            65.78331        112.9925
# 2            71.51521        136.4873
# 3            69.39874        153.0269
# 4            68.21660        142.3354
# 5            67.78781        144.2971
# ...               ...             ...
# 24996        69.50215        118.0312
# 24997        64.54826        120.1932
# 24998        64.69855        118.2655
# 24999        67.52918        132.2682
# 25000        68.87761        124.8742
#
# [25000 rows x 2 columns]

# %% [markdown]
# # 2. 预览数据

# %%
# 查看数据集形状
# Out:
# (25000, 2)

# %%
# 将列名Height(Inches)，Weight(Pounds)修改为Height，Weight
# df.columns = ['Height','Weight']

# %%
# 查看基本的统计特征
# Out:
#              Weight        Height
# count  25000.000000  25000.000000
# mean      67.993114    127.079421
# std        1.901679     11.660898
# min       60.278360     78.014760
# 25%       66.704397    119.308675
# 50%       67.995700    127.157750
# 75%       69.272958    134.892850
# max       75.152800    170.924000

# %% [markdown]
# # 3. 绘制身高分布直方图

# %%
# 创建画布（10,5），分辨率200

# 绘制身高直方图，100个条形

# x轴标签身高，y轴标签身高平次

# 标题身高分布直方图，大小15

# 保存图片到result文件夹
plt.savefig(r'result/身高分布直方图.png',bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4. 绘制身高和体重柱状图

# %% [markdown]
# ## 4.1 等级划分

# %%
# 将身高数据分成5个等宽的区间，并用标签['H1','H2','H3','H4','H5']来标记每个区间，统计每个区间的数量，并按索引升序排列，赋值给变量hCounts
# Out:
# Height
# H1      125
# H2     3708
# H3    14074
# H4     6700
# H5      393
# Name: count, dtype: int64

# %%
# 将体重数据分成5个等宽的区间，并用标签['W1', 'W2', 'W3', 'W4', 'W5']来标记每个区间，统计每个区间的数量，并按索引升序排列，赋值给变量wCounts
# Out:
# Weight
# W1      145
# W2     4251
# W3    14050
# W4     6229
# W5      325
# Name: count, dtype: int64

# %% [markdown]
# ## 4.2 绘制柱状图

# %%
# 绘制身高体重不同等级的柱状图
# 创建画布


# 子图1，身高柱状图，x和y轴标签分布为身高等级，身高等级频次，标题身高柱状图，增加数据标签

    
# 子图2，体重柱状图，x和y轴标签分布为体重等级，体重等级频次，标题体重柱状图，增加数据标签


# 调整两个子图的间距


# 保存
plt.savefig(r'result/身高柱状图及体重柱状图.png', dpi=200, bbox_inches='tight')
plt.show()

# %% [markdown]
# # 5. 绘制箱线图

# %%
# 创建画布


# 子图1，身高箱线图，y轴标签Height，x轴刻度为空，标题身高箱线图

# 子图2，体重箱线图，y轴标签Weight，x轴刻度为空，标题体重箱线图

# 保存
plt.savefig(r'result/身高柱状图及体重箱线图.png', dpi=200, bbox_inches='tight')
plt.show()
