# %%
print("hello,world")

# %%
print("hello,python")

# %% [markdown]
# ## 基本数据类型
# - int
# - float
# - str
# - bool

# %%
age = 22

rate = 0.15

name = "xiaoming"

is_vip = True

# %% [markdown]
# ## type()  查看数据类型

# %%
type(age)

# %% [markdown]
# ## 类型转换 int() /str() / float()

# %%
age = "20"

age_int = int(age)
type(age_int)

# %%
pi = 3.99

print(int(pi))
#截断小数，round()四舍五入

# %% [markdown]
# ## f-string 格式化

# %%
name = "小明"
score = 95

print(f"姓名：{name},分数：{score}")

# %% [markdown]
# ## 变量名命名规则
# - 只能字母、数字、下划线
# - 不能数字开头
# - 区分大小写
# - 不能是python关键字

# %%
int("3.14")

# %%
int(float("3.14"))

# %% [markdown]
# ## == 比较值是否相等，is 比较是否同一个对象（内存地址）

# %% [markdown]
# ## 变量名是指针（引用），指向内存中的数据对象
